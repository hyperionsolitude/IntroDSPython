# %%
"4" + "67"

# %%
"hello" + "42"

# %%
##################
# EXAMPLE: strings 
##################
hi = "hello there"
name = "ana"
greet = hi + name  
print(greet)

# %%
greeting = hi + " " + name
print(greeting)

# %%
silly = (hi+" ")*3
print(silly)

# %%
###################
# EXAMPLE: output 
###################
x = 1
print(x)

# %%
type(x)

# %%
x_str

# %%
x_str = str(x)
type(x_str)

# %%
print("my fav number is", x,".", "x=", x)

# %%
print("my fav number is", x_str + "." + "x=" + x_str)

# %%
###################
# EXAMPLE: input
###################
text= input("Type anything... ")
print(5*text)

# %%
type(int(text))

# %%
int(text)

# %%
num = int(input("Type a number... "))
print(5*num)

# %%
a = float(input("Enter a value: "))
a

# %%
b = int(input("Enter an integer value: "))
b

# %%
pset_time= 15
sleep_time= 8
print(sleep_time> pset_time)

# %%
derive = True
drink = False
both = drink and derive
print(both)

# %%
int(derive)

# %%
s = "Hello"
"h" in s, "er" in s, "llo" in s, "Hel" in s

# %%
1 < 2 and 3==3

# %%
1 < 2 and 3==4

# %%
1 < 2 or 3==4

# %%
3<2 or 3==4

# %%
int(3==4)

# %%
###################
# EXAMPLE: conditionals/branching 
###################
target = "42"
guess = input("Your Guess is: ")
if guess == target:
    print("Correct!")
    print("That's the End")
    
print("Real End")

# %%
target = "42"
guess = input("Your Guess is: ")
if guess == target:
    print("Correct!")
    print("Bravo!")
else: 
    print("Incorrect!")
    print("Guess Again")

# %%
x = float(input("Enter a number for x: "))
y = float(input("Enter a number for y: "))
if x == y:
    print("x and y are equal", x, y)
    if y != 0:
        print("therefore, x / y is", x/y)
elif x < y:
    print("x is smaller")
else:
    print("y is smaller")
    
print("thanks!")

# %%
###################
# EXAMPLE: remainder 
###################
num = int(input("Enter a number: "))
if num % 2 == 0:
    print("number is even")
else:
    print("number is odd")

# %%
###################
# EXAMPLE: while loops 
# Try expanding this code to show a sad face if you go right
# twice and flip the table any more times than that. 
# Hint: use a counter
###################
n = input("You are in the Lost Forest\n****************\n****************\n :)\n****************\n****************\nGo left or right? ")
while n == "right" or n == "Right":
    n = input("You are in the Lost Forest\n****************\n******       ***\n  (╯°□°）╯︵ ┻━┻\n****************\n****************\nGo left or right? ")
print("\nYou got out of the Lost Forest!\n\o/")

# %%
n = input("You are in the Lost Forest - Go left or right? ")

while n != "left" and n != "Left":
    if n == "right" or n == "Right":
        n = input("You are in the Lost Forest - Go left or right? ")
    else:
        n = input("Please select right or Right or left or Left ")
    
print("\nYou got out of the Lost Forest!\n\o/")

# %%
n = input("You are in the Lost Forest\n****************\n****************\n :)\n****************\n****************\nGo left or right? ")

Left

while n != "left" and n != "Left":
    if (n != "right" and n != "Right"):
        n = input("Please choose left or Left or Right or right")
    else:
        n = input("You are in the Lost Forest\n****************\n******       ***\n  (╯°□°）╯︵ ┻━┻\n****************\n****************\nGo left or right? ")
print("\nYou got out of the Lost Forest!\n\o/")

# %%
n = input("You are in the Lost Forest\n****************\n****************\n :)\n****************\n****************\nGo left or right? ")

auxvariable  = True

while auxvariable:
    if (n == "left" or n == "Left"):
        auxvariable = False
    elif (n == "right" or n == "Right"):
        n = input("You are in the Lost Forest\n****************\n******       ***\n  (╯°□°）╯︵ ┻━┻\n****************\n****************\nGo left or right? ")
    else:
        n = input("Please choose left or Left or Right or right")
        
print("\nYou got out of the Lost Forest!\n\o/")

# %%
n = input("You are in the Lost Forest\n****************\n****************\n :)\n****************\n****************\nGo left or right? ")

while n != "left" and n != "Left":
    if n == "right" or n == "Right":
        n = input("You are in the Lost Forest\n****************\n******       ***\n  (╯°□°）╯︵ ┻━┻\n****************\n****************\nGo left or right? ")
    else:
        n = input("Please enter left or Left or right or Right")
print("\nYou got out of the Lost Forest!\n\o/")

# %%
n = input("Go left/Left or right/Right? ")
while n != "right" and n != "Right" and n != "left" and n != "Left ":
    n = input("Please choose one of the options:Go left/Left or right/Right?")

while n == "right" or n == "Right":
    n = input("Go left/Left or right/Right?")
    while n != "right" and n != "Right" and n != "left" and n != "Left ":
        n = input("Please choose one of the options:Go left/Left or right/Right?")
    
print("\nYou got out of the Lost Forest!\n\o/")

#left, Left, right, Right

# %%
n = input("Go left/Left or right/Right? ")

while n == "right" or n == "Right" or n == "left" or n == "Left ":
    if (n=="left") or (n == "Left"):
        print("\nYou got out of the Lost Forest!\n\o/")
    else:
        n = input("Go left/Left or right/Right?")

# %%
a = 0
while a<=5:
    print("vestel", a)
    #a = a + 1
    a +=1

# %%
a

# %%
n = 0

while n < 15:
    n = n+3
    print(n)

print("END")

# %%
###################
# Assignment: Using while loops count (a) from 4 to 39 with an increment of 5, (b) from 18 to 3 backwards with an increment of 2.
###################

n = 18
while n > 3:
    print(n)
    n -=2

# %%
n

# %%
###################
# Assignment: Calculate 1^p+2^p+⋯+10^p for p = 1, 2, ... 10
###################

# %%
1^2+2^2+....10^2

# %%
1^3+2^3+....10^3

# %%
p = 1

while p<11:
    print("p= ", p)
    base = 1
    summation = 1**p+2**p+3**p
    print(summation)
    p +=1

# %%
p = 1

while p<11:
    print("p= ", p)
    base = 1
    summation = 0
    while base <56:
        #print("base= ", base)
        summation += base**p
        base+=1
    print(summation)
    p +=1

# %%
p = 1
TotalSummation = 0
while p < 11:
    #print("p=", p)
    summation = 0
    i = 1
    while  i < 11:
        #print("   ", i, i**p)
        summation += i**p
        i +=1
    print("summation =", p, summation)
    TotalSummation +=summation
    p +=1
    
print(TotalSummation)

# %%
for p in range(1,11):
    summation = 0
    print("p=", p)
    for i in range(1,11):
        summation += i**p
    print("summation=",summation)
#     if (summation>10000):
#         break

# %%
for p in range(5):
    print(p)

# %%
for p in range(1,5):
    print(p)
    p = p-1

# %%
###################
# EXAMPLE: for loops
###################
for n in range(2, 15, 3):
    print(n)

# %%
for n in range(5):
    print(n)
    n=n+1
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
mysum = 0
for i in range(10):
    mysum += i
print(mysum)
# Out:
# 45

# %%
mysum = 0
for i in range(7, 10):
    mysum += i
print(mysum)
# Out:
# 24

# %%
mysum = 0
for i in range(5, 101, 2):
    mysum += i
    print(mysum)
    if mysum > 10:
        break
    print("Vestel")
print(mysum)
# Out:
# 5
# Vestel
# 12
# 12

# %%
n = 0 
summation  = 0 
while n <10:
    n+=1
    summation +=n
    print(summation)
    if summation >20:
        break
    print("Yaz", n)
# Out:
# 1
# Yaz 1
# 3
# Yaz 2
# 6
# Yaz 3
# 10
# Yaz 4
# 15
# Yaz 5
# 21

# %%
mysum = 0
for i in range(5, 11, 2):
    mysum += i
    if mysum > 25:
        break
        mysum += 1
print(mysum)

# %%
for s in ["This", "is", "fun"]:
    print(s)
# Out:
# This
# is
# fun

# %%
sum=0
for x in (4, 5, 2, -4, 1, 10):
    print(x)
    sum += x
print(sum)
# Out:
# 4
# 5
# 2
# -4
# 1
# 10
# 18

# %%
sum = 0
while True:
    x = int(input("Enter a positive integer 0-100 (to stop enter -1): "))
    if x == -1:
        break
    if x < 0 or x > 100:
        print("should be between 0-100!")
        continue
    sum += x
print("Total:", sum)
# Out:
# Enter a positive integer 0-100 (to stop enter -1): 20
# Enter a positive integer 0-100 (to stop enter -1): 20
# Enter a positive integer 0-100 (to stop enter -1): 20
# Enter a positive integer 0-100 (to stop enter -1): -32
# should be between 0-100!
# Enter a positive integer 0-100 (to stop enter -1): 10
# Enter a positive integer 0-100 (to stop enter -1): 99
# Enter a positive integer 0-100 (to stop enter -1): -1
# Total: 169

# %%
###################
# EXAMPLE: perfect squares
###################

x = int(input("Enter an integer: "))

notPerfectSquare = True

for i in range(1, x+1):
    print("Trying i", i)
    if i*i == x:
        print("It is a perfect square")
        notPerfectSquare = False
        break
    elif i*i>x:
        break

if notPerfectSquare:
    print("It is not a perfect square")
# Out:
# Enter an integer: -36
# It is not a perfect square

# %%
####################
## TEST YOURSELF!
## Modify the perfect squares example to check 
## whether a given integer is a prime number or not
####################    


nPrimes = 0
for x in range(2, 20000):

    Prime= True
    for i in range(2, x):
        #print("Trying i", i)
        if x % i == 0:
            #print(x, "It is not a prime number")
            Prime = False
            break
        elif i*i>x:
            break

    if Prime:
        print(x, "It is a prime number")
        nPrimes+=1
        
        
print(nPrimes)
# Out:
# 2 It is a prime number
# 3 It is a prime number
# 5 It is a prime number
# 7 It is a prime number
# 11 It is a prime number
# 13 It is a prime number
# 17 It is a prime number
# 19 It is a prime number
# 23 It is a prime number
# 29 It is a prime number
# 31 It is a prime number
# 37 It is a prime number
# 41 It is a prime number
# 43 It is a prime number
# 47 It is a prime number
# 53 It is a prime number
# 59 It is a prime number
# 61 It is a prime number
# 67 It is a prime number
# 71 It is a prime number
# 73 It is a prime number
# 79 It is a prime number
# 83 It is a prime number
# 89 It is a prime number
# 97 It is a prime number
# 101 It is a prime number
# 103 It is a prime number
# 107 It is a prime number
# 109 It is a prime number
# 113 It is a prime number
# 127 It is a prime number
# 131 It is a prime number
# 137 It is a prime number
# 139 It is a prime number
# 149 It is a prime number
# 151 It is a prime number
# 157 It is a prime number
# 163 It is a prime number
# ...

# %%
###################
# EXAMPLE: perfect squares
###################
ans = 0
neg_flag = False
x = int(input("Enter an integer: "))
if x < 0:
    neg_flag = True
while ans**2 < x:
    print(ans)
    ans = ans + 1
    
if ans**2 == x:
    print("Square root of", x, "is", ans)
else:
    print(x, "is not a perfect square")
    if neg_flag:
        print("Just checking... did you mean", -x, "?")

# %%
####################
## TEST YOURSELF!
## Modify the perfect squares example to check 
## whether a given integer is a prime number or not
####################

# %%
for i in range(1,30000,2):
    if i==1:
        print(i, "is not a prime number")
    elif i==2:
        print(i, "is a prime number")
    else: 
        flag = True
        for j in range(2,i):
            if i%j == 0:
                flag = False
                break
            elif (j**2>i):
                break
        if flag:
            print(i, "is a prime number")

# %%
####################
## TEST YOURSELF!
## Given a mortgage amount, the interest rate and monthly payment  
## determine how many months it will take to repay the loan
####################

# %%
####################
## TEST YOURSELF!
## Given a mortgage amount, the interest rate and repayment duration
## determine the monthly payment amount
####################
